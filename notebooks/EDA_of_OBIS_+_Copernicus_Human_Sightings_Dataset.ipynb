# %% [markdown]
# <a href="https://colab.research.google.com/github/Patrick190508/whaleshark-mafia-island/blob/main/notebooks/EDA_of_OBIS_%2B_Copernicus_Human_Sightings_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA of OBIS + Copernicus Human Sightings Dataset

# %% [markdown]
# ## Step 1 - Importing the Dataset from Github
